# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('../../data/athlete_events.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Usar la clausula de numpy para lo siguiente:
#Si la edad es > 26 años, al peso restarle 2kg.

df['Weight'] = np.where(df['Age'] > 26, df['Weight'] - 2, df['Weight'])
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    87.0
# 271112  135570                  Piotr ya   M  27.0   176.0    57.0
# 271113  135570                  Piotr ya   M  27.0   176.0    57.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    94.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    94.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Si la edad >  30 y NOC es USA, escribir "Distinguished" del nombre

df['Name'] = np.where((df['Age'] > 30) & (df['NOC'] == 'USA'), 'Distinguished ' +df['Name'],df['Name'])
df.sort_values(by='NOC', ascending=False)
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    87.0
# 271112  135570                  Piotr ya   M  27.0   176.0    57.0
# 271113  135570                  Piotr ya   M  27.0   176.0    57.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    94.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    94.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Genere una funcion que remplace M -> MALE y F -> FEMALE
def remplazo(sex):
    if sex == 'M':
        return 'Male'
    elif sex == 'F':
        return 'Female'
    else:
        return sex  


df['Sex'] = df['Sex'].apply(remplazo)
df
# Out:
#             ID                      Name     Sex   Age  Height  Weight  \
# 0            1                 A Dijiang    Male  24.0   180.0    80.0
# 1            2                  A Lamusi    Male  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby    Male  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye    Male  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink  Female  21.0   185.0    82.0
# ...        ...                       ...     ...   ...     ...     ...
# 271111  135569                Andrzej ya    Male  29.0   179.0    87.0
# 271112  135570                  Piotr ya    Male  27.0   176.0    57.0
# 271113  135570                  Piotr ya    Male  27.0   176.0    57.0
# 271114  135571        Tomasz Ireneusz ya    Male  30.0   185.0    94.0
# 271115  135571        Tomasz Ireneusz ya    Male  34.0   185.0    94.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
# Ahora con lambda haga quee el "Team" -> mayusculas
df['Team'] = df['Team'].apply(lambda x: x.upper())
df
# Out:
#             ID                      Name     Sex   Age  Height  Weight  \
# 0            1                 A Dijiang    Male  24.0   180.0    80.0
# 1            2                  A Lamusi    Male  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby    Male  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye    Male  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink  Female  21.0   185.0    82.0
# ...        ...                       ...     ...   ...     ...     ...
# 271111  135569                Andrzej ya    Male  29.0   179.0    87.0
# 271112  135570                  Piotr ya    Male  27.0   176.0    57.0
# 271113  135570                  Piotr ya    Male  27.0   176.0    57.0
# 271114  135571        Tomasz Ireneusz ya    Male  30.0   185.0    94.0
# 271115  135571        Tomasz Ireneusz ya    Male  34.0   185.0    94.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
# Ordene el df por edad y nombre en orden descendiente (mayor a menor)
df = df.sort_values(by=['Age', 'Name'], ascending=[False, False])
df
# Out:
#             ID                                      Name     Sex   Age  \
# 257054  128719      Distinguished John Quincy Adams Ward    Male  97.0
# 98118    49663               Distinguished Winslow Homer    Male  96.0
# 60861    31173  Distinguished Thomas Cowperthwait Eakins    Male  88.0
# 60862    31173  Distinguished Thomas Cowperthwait Eakins    Male  88.0
# 60863    31173  Distinguished Thomas Cowperthwait Eakins    Male  88.0
# ...        ...                                       ...     ...   ...
# 33013    16990                                A. Buydens    Male   NaN
# 30535    15740                                   A. Brun  Female   NaN
# 4015      2316                                 A. Albert    Male   NaN
# 528        300                           A. Abdul Razzak    Male   NaN
# 529        300                           A. Abdul Razzak    Male   NaN
#
#         Height  Weight                                            Team  NOC  \
# ...

# %%
# Elimine columa ID y Event y genere un nuevo df
df_nuevo = df.drop(columns=['ID', 'Event'])
df_nuevo
# Out:
#                                             Name     Sex   Age  Height  \
# 257054      Distinguished John Quincy Adams Ward    Male  97.0     NaN
# 98118                Distinguished Winslow Homer    Male  96.0     NaN
# 60861   Distinguished Thomas Cowperthwait Eakins    Male  88.0     NaN
# 60862   Distinguished Thomas Cowperthwait Eakins    Male  88.0     NaN
# 60863   Distinguished Thomas Cowperthwait Eakins    Male  88.0     NaN
# ...                                          ...     ...   ...     ...
# 33013                                 A. Buydens    Male   NaN     NaN
# 30535                                    A. Brun  Female   NaN     NaN
# 4015                                   A. Albert    Male   NaN     NaN
# 528                              A. Abdul Razzak    Male   NaN   178.0
# 529                              A. Abdul Razzak    Male   NaN   178.0
#
#         Weight                                            Team  NOC  \
# ...

# %%
# Filtre columna por Name, Sex, Age, NOC, Year 
df_filtrado = df[['Name', 'Sex', 'Age', 'NOC', 'Year']]
df_filtrado
# Out:
#                                             Name     Sex   Age  NOC  Year
# 257054      Distinguished John Quincy Adams Ward    Male  97.0  USA  1928
# 98118                Distinguished Winslow Homer    Male  96.0  USA  1932
# 60861   Distinguished Thomas Cowperthwait Eakins    Male  88.0  USA  1932
# 60862   Distinguished Thomas Cowperthwait Eakins    Male  88.0  USA  1932
# 60863   Distinguished Thomas Cowperthwait Eakins    Male  88.0  USA  1932
# ...                                          ...     ...   ...  ...   ...
# 33013                                 A. Buydens    Male   NaN  BEL  1924
# 30535                                    A. Brun  Female   NaN  FRA  1900
# 4015                                   A. Albert    Male   NaN  FRA  1900
# 528                              A. Abdul Razzak    Male   NaN  IRQ  1960
# 529                              A. Abdul Razzak    Male   NaN  IRQ  1960
#
# [271116 rows x 5 columns]

# %%
# Filtre por renglones por edades de 21 a 23 y por año de 2000 a 2002
df_8 = df[(df['Age'] >= 21) & (df['Age'] <= 23) & (df['Year'] >= 2000) & (df['Year'] <= 2002)]
df_8
# Out:
#            ID               Name   Sex   Age  Height  Weight            Team  \
# 2857     1587       zdemir Akbal  Male  23.0   178.0    58.0          TURKEY
# 2858     1587       zdemir Akbal  Male  23.0   178.0    58.0          TURKEY
# 158246  79453         ubomr Mick  Male  23.0   181.0    81.0        SLOVAKIA
# 158247  79453         ubomr Mick  Male  23.0   181.0    81.0        SLOVAKIA
# 105874  53562          tpn Janek  Male  23.0   188.0    80.0  CZECH REPUBLIC
# ...       ...                ...   ...   ...     ...     ...             ...
# 59654   30563   Adrian Duminicel  Male  21.0   186.0    96.0         ROMANIA
# 37046   19052          Adnan ati  Male  21.0   180.0    71.0         GERMANY
# 113114  57308     Adil El-Kaouch  Male  21.0   170.0    62.0         MOROCCO
# 80007   40606  Adam Bart Gitsham  Male  21.0   175.0    67.0       AUSTRALIA
# 9599     5259   Abdessalem Arous  Male  21.0   180.0    81.0         TUNISIA
#
# ...
