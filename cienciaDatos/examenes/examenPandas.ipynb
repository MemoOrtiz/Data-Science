# %%
import numpy as numpy
import pandas as pd

# %%
df = pd.read_csv('../../data/athlete_events.csv')
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Si la edad es de > 26 años al peso restarle 2kg



#df['Age'] = numpy.where(df['Age'] > 26, df['Weight']-2.0, df)
df1 = df[df['Age'] > 26]

df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6           Per Knut Aaland   M  31.0   188.0    75.0
# 11           6           Per Knut Aaland   M  31.0   188.0    75.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# ...

# %%
df1['Weight'] = numpy.where(True, df1['Weight']-2,df1['Weight'])
df1
# Out:
# /var/folders/9c/0nd6phzx429bzy7lvvwctvdm0000gn/T/ipykernel_19188/3651272073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Weight'] = numpy.where(True, df1['Weight']-2,df1['Weight'])
#             ID                      Name Sex   Age  Height  Weight  \
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    80.0
# 9            5  Christine Jacoba Aaftink   F  27.0   185.0    80.0
# 10           6           Per Knut Aaland   M  31.0   188.0    73.0
# 11           6           Per Knut Aaland   M  31.0   188.0    73.0
# ...        ...                       ...  ..   ...     ...     ...
# ...

# %%
df2 = df[df['Age'] >30]
df2 = df2[df2['NOC'] == 'USA']
df2
# Out:
#             ID                     Name Sex   Age  Height  Weight  \
# 10           6          Per Knut Aaland   M  31.0   188.0    75.0
# 11           6          Per Knut Aaland   M  31.0   188.0    75.0
# 12           6          Per Knut Aaland   M  31.0   188.0    75.0
# 13           6          Per Knut Aaland   M  31.0   188.0    75.0
# 14           6          Per Knut Aaland   M  33.0   188.0    75.0
# ...        ...                      ...  ..   ...     ...     ...
# 270206  135177  Walter Ward Zobell, Jr.   M  34.0   173.0    71.0
# 270352  135238           William Zorach   M  45.0     NaN     NaN
# 270794  135427        Frank Thomas Zuna   M  31.0   175.0    69.0
# 270851  135458                 Rami Zur   M  31.0   175.0    77.0
# 270852  135458                 Rami Zur   M  31.0   175.0    77.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 10      United States  USA  1992 Winter  1992  Winter  Albertville
# ...

# %%
df2['Name'] = numpy.where(True, df2['Name'] , df2['Name'])
df2
# Out:
#             ID                     Name Sex   Age  Height  Weight  \
# 10           6          Per Knut Aaland   M  31.0   188.0    75.0
# 11           6          Per Knut Aaland   M  31.0   188.0    75.0
# 12           6          Per Knut Aaland   M  31.0   188.0    75.0
# 13           6          Per Knut Aaland   M  31.0   188.0    75.0
# 14           6          Per Knut Aaland   M  33.0   188.0    75.0
# ...        ...                      ...  ..   ...     ...     ...
# 270206  135177  Walter Ward Zobell, Jr.   M  34.0   173.0    71.0
# 270352  135238           William Zorach   M  45.0     NaN     NaN
# 270794  135427        Frank Thomas Zuna   M  31.0   175.0    69.0
# 270851  135458                 Rami Zur   M  31.0   175.0    77.0
# 270852  135458                 Rami Zur   M  31.0   175.0    77.0
#
#                  Team    NOC        Games  Year  Season         City  \
# 10      United States  False  1992 Winter  1992  Winter  Albertville
# ...

# %%
def remplazo(df):
    if df[df['Sex']] == 'M':
        df[df['Sex']

# %%
df_ord = df.sort_index(df['Age'],ascending= True)
df_ord
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_ord = df.sort_index(df['Age'],ascending= True)
#       2 df_ord
#
# TypeError: DataFrame.sort_index() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given

# %%
#Filtre por renglones edades de 21 a 23 años por año de 2000 a 2002

# %%
#Ordene el df por edad y nombre en orden descendiente(mayor a menor)

# %%
#Elimine la columna ID y Event y genere un nuevo df

# %%
#Filtre por columna Name, Sex,Age,NOC, Year

# %%
#con lambda haga que el team -> mayusculas
