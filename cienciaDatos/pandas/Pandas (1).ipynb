# %%
import numpy as np
import pandas as pd

# %%
#Leer el archivo dataset la r significa row
df = pd.read_csv('../../data/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Metodo head
#Nos permite visualizar los primeros 5 renglones del data frame
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Tail nos permite ver los últimos 5 renglones 
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#mostrar los primeros 10 renglones
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
#los ultimos 10 renglones
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
#FILTRAR POR RENGLONES 
df.Pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
df["Pclass"]
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
#Nos mostrara false todo lo que sea distinta de primera clase y true si es primera clase
df.Pclass == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Pclass, Length: 418, dtype: bool

# %%
df["Pclass"] == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Pclass, Length: 418, dtype: bool

# %%
#Generar dataframe para solo mostrar a los de primera clase 
#Creamos un data frame para mostrar toda la informacion del dataframe primera clase
df_1st = df[df.Pclass == 1]
df_1st
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Generar un nuevo data frame donde solo filtremos a los que sobrevivieron
df_sobre = df[df.Survived == 1]
df_sobre
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df_murieron = df[(df.Survived == 0)]
df_murieron
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
# Lista de edades específicas que queremos filtrar
ages = [20,21,22]

# %%
# Filtrar el DataFrame 'df' para incluir solo las filas donde la columna 'Age' contiene valores en la lista 'ages'
df_ages = df[df["Age"].isin(ages)]
df_ages
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 9            901         0       3
# 17           909         0       3
# 23           915         0       1
# 26           918         1       1
# 37           929         1       3
# 52           944         1       2
# 63           955         1       3
# 71           963         0       3
# 90           982         1       3
# 98           990         1       3
# 106          998         0       3
# 126         1018         0       3
# 147         1039         0       3
# 169         1061         1       3
# 176         1068         1       2
# 186         1078         1       2
# 221         1113         0       3
# 222         1114         1       2
# 223         1115         0       3
# 231         1123         1       1
# 232         1124         0       3
# 235         1127         0       3
# 237         1129         0       3
# 246         1138         1       2
# ...

# %%
# Filtrar el DataFrame 'df' para incluir solo las filas donde:
# 1. La columna 'Age' contiene valores en la lista 'ages' o sea 20,21,22
# 2. La columna 'Pclass' es igual a 1 omsea primera clase
df_filtrado = df[df["Age"].isin(ages) & (df["Pclass"] == 1)]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23           915         0       1  Williams, Mr. Richard Norris II    male
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 231         1123         1       1         Willard, Miss. Constance  female
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 23   21.0      0      1  PC 17597  61.3792   NaN        C
# 26   22.0      0      1    113509  61.9792   B36        C
# 231  21.0      0      0    113795  26.5500   NaN        S
# 402  22.0      0      1    112378  59.4000   NaN        C

# %%
#Ejercicio1 Filtrar el data frame por genero Y decir cuantos fueron male y female
df_male = df[df['Sex'] == 'male']
df_female = df[df['Sex'] == 'female']
# Contar cuántos fueron male y female
num_male = len(df_male)
num_female = len(df_female)

# Mostrar los resultados
print(f"males: {num_male}")
print(f"females: {num_female}")
# Out:
# males: 266
# females: 152

# %%
#Filtrar  nuestro data frame por edades de 30 a 35 años y decir cuantos son
#df_30_35 = df[df['Age'].between(30, 35)]
df_30_a_35 = df[(df['Age'] >= 30) & (df['Age'] <= 35)]
df_30_a_35.__len__()
# Out:
# 42

# %%
#Filtrar aquellos pasajeros que sobrevivieron y que están en segunda clase 
df_aaa = df[(df['Survived'] == 1) & (df['Pclass'] == 2)]
df_aaa
# Out:
#      PassengerId  Survived  Pclass  \
# 15           907         1       2
# 43           935         1       2
# 52           944         1       2
# 65           957         1       2
# 119         1011         1       2
# 120         1012         1       2
# 162         1054         1       2
# 175         1067         1       2
# 176         1068         1       2
# 178         1070         1       2
# 186         1078         1       2
# 203         1095         1       2
# 213         1105         1       2
# 220         1112         1       2
# 222         1114         1       2
# 238         1130         1       2
# 241         1133         1       2
# 246         1138         1       2
# 248         1140         1       2
# 250         1142         1       2
# 258         1150         1       2
# 262         1154         1       2
# 275         1167         1       2
# 296         1188         1       2
# 326         1218         1       2
# ...

# %%
#Filtrar aquellos pasajeros que sobrevivieron están en segunda clase y tienen una edad de 20 a 22 años y saber cuantos son.
edad = [20,21,22]
df_sobrevivientes = df[(df['Survived'] == 1) & (df['Pclass'] == 2) & (df['Age'].isin(edad))]
df_sobrevivientes
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 52           944         1       2          Hocking, Miss. Ellen Nellie""
# 176         1068         1       2                   Sincock, Miss. Maude
# 186         1078         1       2   Phillips, Miss. Alice Frances Louisa
# 222         1114         1       2             Cook, Mrs. (Selena Rogers)
# 246         1138         1       2  Karnes, Mrs. J Frank (Claire Bennett)
# 275         1167         1       2    Bryhl, Miss. Dagmar Jenny Ingeborg
#
#         Sex   Age  SibSp  Parch        Ticket   Fare Cabin Embarked
# 52   female  20.0      2      1         29105  23.00   NaN        S
# 176  female  20.0      0      0    C.A. 33112  36.75   NaN        S
# 186  female  21.0      0      1   S.O./P.P. 2  21.00   NaN        S
# 222  female  22.0      0      0   W./C. 14266  10.50   F33        S
# 246  female  22.0      0      0  F.C.C. 13534  21.00   NaN        S
# ...

# %%
print(df_sobrevivientes.__len__())
# Out:
# 6

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../data/tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Filtrar Renglones

# %%
df_pClas1 = df[df["Pclass"] == 1] 
df_pClas1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ages = [20,21,22]
df_filtrado = df[df["Age"].isin(ages) & (df["Pclass"] == 1)]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23           915         0       1  Williams, Mr. Richard Norris II    male
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 231         1123         1       1         Willard, Miss. Constance  female
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 23   21.0      0      1  PC 17597  61.3792   NaN        C
# 26   22.0      0      1    113509  61.9792   B36        C
# 231  21.0      0      0    113795  26.5500   NaN        S
# 402  22.0      0      1    112378  59.4000   NaN        C

# %%
#Utilizar parentesis
df_filtrado2 = df[(df["Pclass"] == 2) & (df["Survived"] == 1)]
df_filtrado2.shape
# Out:
# (30, 12)

# %%
#Filtrado por columnas
df_filtrado_Nombre = df.filter(["Name","Sex","Age"])
df_filtrado_Nombre
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
#Eliminar columnas 
df_new2 = df.drop(["Cabin","Embarked","SibSp","Parch"],axis = 1)
df_new2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %%
#Ejercicio 
#Dado el siguiente data frame filtrarlo de tal manera que solo aparezca, nombre, genero y edad
#Una vez filtrado, filtrar que solo aparezcan los de genero  masculino y los de edad de 20 22 años


df_filtro = df.filter(["Name","Sex","Age"])
df_filtro
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
df_filtroNuevo = df_filtro[(df_filtro["Sex"] == "male") & (df_filtro["Age"].isin(ages))]
df_filtroNuevo
# Out:
#                                              Name   Sex   Age
# 9                         Davies, Mr. John Samuel  male  21.0
# 17                              Assaf, Mr. Gerios  male  21.0
# 23                Williams, Mr. Richard Norris II  male  21.0
# 71                             Minkoff, Mr. Lazar  male  21.0
# 106                           Buckley, Mr. Daniel  male  21.0
# 126                      Brobeck, Mr. Karl Rudolf  male  22.0
# 147                              Davies, Mr. Evan  male  22.0
# 221                        Reynolds, Mr. Harold J  male  21.0
# 223                 Karlsson, Mr. Einar Gervasius  male  21.0
# 232                       Wiklund, Mr. Karl Johan  male  21.0
# 235                        Vendel, Mr. Olof Edvin  male  20.0
# 237                           Baccos, Mr. Raffull  male  20.0
# 251      Abrahamsson, Mr. Abraham August Johannes  male  20.0
# 259                      Midtsjo, Mr. Karl Albert  male  21.0
# ...

# %%
#Filtrar por sobrevivientes, nombre,edad y Fare
#Una vez filtrado, filtrar de tal manera los que fueron femenino y que sobrevivieron
df_filt = df.filter(["Sex","Survived","Name","Age","Fare"])
df_filt
# Out:
#         Sex  Survived                                          Name   Age  \
# 0      male         0                              Kelly, Mr. James  34.5
# 1    female         1              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2      male         0                     Myles, Mr. Thomas Francis  62.0
# 3      male         0                              Wirz, Mr. Albert  27.0
# 4    female         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..      ...       ...                                           ...   ...
# 413    male         0                            Spector, Mr. Woolf   NaN
# 414  female         1                  Oliva y Ocana, Dona. Fermina  39.0
# 415    male         0                  Saether, Mr. Simon Sivertsen  38.5
# 416    male         0                           Ware, Mr. Frederick   NaN
# 417    male         0                      Peter, Master. Michael J   NaN
#
#          Fare
# 0      7.8292
# 1      7.0000
# 2      9.6875
# 3      8.6625
# ...

# %%
df_su = df_filt[(df_filt["Sex"] == "female") & (df_filt["Survived"] == 1)]
df_su
# Out:
#         Sex  Survived                                             Name   Age  \
# 1    female         1                 Wilkes, Mrs. James (Ellen Needs)  47.0
# 4    female         1     Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 6    female         1                             Connolly, Miss. Kate  30.0
# 8    female         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 12   female         1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)  23.0
# ..      ...       ...                                              ...   ...
# 409  female         1                        Peacock, Miss. Treasteall   3.0
# 410  female         1                           Naughton, Miss. Hannah   NaN
# 411  female         1  Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0
# 412  female         1                   Henriksson, Miss. Jenny Lovisa  28.0
# 414  female         1                     Oliva y Ocana, Dona. Fermina  39.0
#
#          Fare
# 1      7.0000
# ...

# %%
#Concatenar
df1 = df[df["Pclass"] == 1 ]
df1.shape
# Out:
# (107, 12)

# %%
df2 = df[df["Pclass"] == 2]
df2.shape
# Out:
# (93, 12)

# %%
#concatenar dos frames y reindexar con ignore index
df_final = df1.append(df2, ignore_index = False)
df_final
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9c/0nd6phzx429bzy7lvvwctvdm0000gn/T/ipykernel_97446/2828733009.py in ?()
#       1 #concatenar dos frames y reindexar con ignore index
# ----> 2 df_final = df1.append(df2, ignore_index = False)
#       3 df_final
#
# ~/Documents/NumpyPandas/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df_final = pd.concat([df1,df2],ignore_index = True)
df_final
# Out:
#      PassengerId  Survived  Pclass  \
# 0            903         0       1
# 1            904         1       1
# 2            906         1       1
# 3            912         0       1
# 4            914         1       1
# ..           ...       ...     ...
# 195         1279         0       2
# 196         1285         0       2
# 197         1293         0       2
# 198         1297         0       2
# 199         1298         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Jones, Mr. Charles Cresson    male  46.0      0
# 1        Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 2    Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 3                               Rothschild, Mr. Martin    male  55.0      1
# 4                 Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Ejercicio
#Concatenar los de primera y tercera clase 
df1 = df[df["Pclass"] == 1]
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = df[df["Pclass"] == 3]
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df_f = pd.concat([df1,df2],ignore_index = True)
df_f
# Out:
#      PassengerId  Survived  Pclass  \
# 0            903         0       1
# 1            904         1       1
# 2            906         1       1
# 3            912         0       1
# 4            914         1       1
# ..           ...       ...     ...
# 320         1304         1       3
# 321         1305         0       3
# 322         1307         0       3
# 323         1308         0       3
# 324         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Jones, Mr. Charles Cresson    male  46.0      0
# 1        Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 2    Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 3                               Rothschild, Mr. Martin    male  55.0      1
# 4                 Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_1 = pd.DataFrame({
    "A":[1,2,3,],
    "B":[4,5,6],
})
df_1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df_2 = pd.DataFrame({
    "C":[7,8,9],
    "D":[10,11,12],
})
df_2
# Out:
#    C   D
# 0  7  10
# 1  8  11
# 2  9  12

# %%
df_final = pd.concat([df_1,df_2], axis = 1,ignore_index = True)
df_final
# Out:
#    0  1  2   3
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %%
#Concatenar los de 20 años,30 años y 40 años

# %%
#Ascender Ascendentemente o Viceversa
df_ordenado_edad = df.sort_values(by=["Age"],ascending = False)
df_ordenado_edad
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 236         1128         0       1
# 305         1197         1       1
# 179         1071         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_ordenado_edad_fare = df.sort_values(by=["Age","Fare"],ascending = False)
df_ordenado_edad_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 179         1071         1       1
# 236         1128         0       1
# 305         1197         1       1
# ..           ...       ...     ...
# 211         1103         0       3
# 163         1055         0       3
# 116         1008         0       3
# 133         1025         0       3
# 266         1158         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Construya un dataframe de 4 filas y 4 columnas y concatenenlo con otro data frame de 8 filas y 4 columnas
#la concatenacion vaa  ser vertical
df_c = pd.DataFrame({
    "A": [1,2,3,4],
    "B": [5,6,7,8],
    "C": [9,10,11,12],
    "D":[13,14,15,16],
})
df_b = pd.DataFrame({
    "A": [17,18,19,20,21,22,23,24],
    "B": [25,26,27,28,29,30,31,32],
    "C": [33,34,35,36,37,38,39,40],
    "D": [41,42,43,44,45,46,47,48],
})
df_con = pd.concat([df_c,df_b])
df_con
# Out:
#     A   B   C   D
# 0   1   5   9  13
# 1   2   6  10  14
# 2   3   7  11  15
# 3   4   8  12  16
# 0  17  25  33  41
# 1  18  26  34  42
# 2  19  27  35  43
# 3  20  28  36  44
# 4  21  29  37  45
# 5  22  30  38  46
# 6  23  31  39  47
# 7  24  32  40  48

# %%
#Utilizando el data frame primero creado lo va a concatenar con otro data frame de 4 filas con 3 columnas y su concatenacion va a ser horizontal
df_d = pd.DataFrame({
    "A": [1,2,3,4],
    "B": [5,6,7,8],
    "C": [9,10,11,12],
})
df_Con = pd.concat([df_c,df_d], axis = 1, ignore_index = True)
df_Con
# Out:
#    0  1   2   3  4  5   6
# 0  1  5   9  13  1  5   9
# 1  2  6  10  14  2  6  10
# 2  3  7  11  15  3  7  11
# 3  4  8  12  16  4  8  12

# %%
#El data frame de titanic va a ordenar los valores de la ultima clase a la primer clase 
df_pclass = df.sort_values(by=["Pclass"],ascending=False)
df_pclass
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 232         1124         0       3
# 249         1141         1       3
# 244         1136         0       3
# 243         1135         0       3
# ..           ...       ...     ...
# 239         1131         1       1
# 158         1050         0       1
# 240         1132         1       1
# 77           969         1       1
# 236         1128         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                     Kelly, Mr. James    male  34.5      0
# 232                            Wiklund, Mr. Karl Johan    male  21.0      1
# 249          Khalil, Mrs. Betros (Zahie Maria" Elias)"  female   NaN      1
# 244          Johnston, Master. William Arthur Willie""    male   NaN      1
# 243                                 Hyman, Mr. Abraham    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Ordenar por numero de ticket y edad
df_or = df.sort_values(by=["Ticket","Age"],ascending = False)
df_or
# Out:
#      PassengerId  Survived  Pclass  \
# 14           906         1       1
# 167         1059         0       3
# 33           925         1       3
# 244         1136         0       3
# 222         1114         1       2
# ..           ...       ...     ...
# 266         1158         0       1
# 191         1083         0       1
# 236         1128         0       1
# 158         1050         0       1
# 335         1227         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 167                            Ford, Mr. Edward Watson    male  18.0      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female   NaN      1
# 244          Johnston, Master. William Arthur Willie""    male   NaN      1
# 222                         Cook, Mrs. (Selena Rogers)  female  22.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../data/tested.csv')

# %%
df_nuevo = df.sort_values(by = ["Age"], ascending = False)

# %%
df.sort_values(by =["Age"])
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %%
def math(x):
    return x + 2

# %%
math(5)
# Out:
# 7

# %%
#Guardar en la columna pclass para que se guarde en la variable la funcion
df["Pclass"] = df["Pclass"].apply(math)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       7
# 1            893         1       7
# 2            894         0       6
# 3            895         0       7
# 4            896         1       7
# ..           ...       ...     ...
# 413         1305         0       7
# 414         1306         1       5
# 415         1307         0       7
# 416         1308         0       7
# 417         1309         0       7
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#En lugar de crear la funcion anterior, llamamos la funcion lambda y lo que queremos que realice 
df_5 = df["Age"].apply(lambda x: x + 2 )
df_5
# Out:
# 0      38.5
# 1      51.0
# 2      66.0
# 3      31.0
# 4      26.0
#        ...
# 413     NaN
# 414    43.0
# 415    42.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df.insert(1, "age", df.pop("Age"))
df
# Out:
#      PassengerId   age  Survived  Pclass  \
# 0            892  36.5         0       5
# 1            893  49.0         1       5
# 2            894  64.0         0       4
# 3            895  29.0         0       5
# 4            896  24.0         1       5
# ..           ...   ...       ...     ...
# 413         1305   NaN         0       5
# 414         1306  41.0         1       3
# 415         1307  40.5         0       5
# 416         1308   NaN         0       5
# 417         1309   NaN         0       5
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ...

# %%
#np.where(Condition, si es True, si es False)
df.head()
# Out:
#    PassengerId   age  Survived  Pclass  \
# 0          892  36.5         0       5
# 1          893  49.0         1       5
# 2          894  64.0         0       4
# 3          895  29.0         0       5
# 4          896  24.0         1       5
#
#                                            Name     Sex  SibSp  Parch  \
# 0                              Kelly, Mr. James    male      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                     Myles, Mr. Thomas Francis    male      0      0
# 3                              Wirz, Mr. Albert    male      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   0.0000   NaN        Q
# 1   363272  22.0000   NaN        S
# 2   240276  24.6875   NaN        Q
# 3   315154   0.0000   NaN        S
# 4  3101298   0.0000   NaN        S

# %%
#Si la condicion es verdadera se le suma 5 al fare si es false no se modifica nada
df['Fare'] = np.where(df["age"] > 40 , df["Fare"] + 5, df["Fare"])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/NumpyPandas/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 2
# ...

# %%
#Ejercicios
#del data frame original, ordenar el fdata frame y crear un data frame con lo siguiente
#Ordenar por clase y sobrevivvientes, de menor a mayor
import numpy as np
import pandas as pd
df_tit = pd.read_csv(r"C:\Users\franc\Downloads\archive (1)\tested.csv")
df = df.sort_values(["Pclass","Survived"])
df
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 266         1158         0       1  DistinguidoDistinguido    male   NaN
# 372         1264         0       1  DistinguidoDistinguido    male  49.0
# 205         1097         0       1  DistinguidoDistinguido    male   NaN
# 94           986         0       1  DistinguidoDistinguido    male  25.0
# 82           974         0       1  DistinguidoDistinguido    male  49.0
# ..           ...       ...     ...                     ...     ...   ...
# 132         1024         1       3  DistinguidoDistinguido  female   NaN
# 367         1259         1       3  DistinguidoDistinguido  female  22.0
# 140         1032         1       3  DistinguidoDistinguido  female  10.0
# 188         1080         1       3  DistinguidoDistinguido  female   NaN
# 365         1257         1       3  DistinguidoDistinguido  female   NaN
#
#      SibSp  Parch      Ticket     Fare        Cabin Embarked
# ...

# %%
#Ordenar por nombre y costo de boleto
df = df.sort_values(["Name","Fare"])
df
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 266         1158         0       1  DistinguidoDistinguido    male   NaN
# 372         1264         0       1  DistinguidoDistinguido    male  49.0
# 21           913         0       3  DistinguidoDistinguido    male   9.0
# 133         1025         0       3  DistinguidoDistinguido    male   NaN
# 116         1008         0       3  DistinguidoDistinguido    male   NaN
# ..           ...       ...     ...                     ...     ...   ...
# 24           916         1       1  DistinguidoDistinguido  female  48.0
# 53           945         1       1  DistinguidoDistinguido  female  28.0
# 69           961         1       1  DistinguidoDistinguido  female  60.0
# 343         1235         1       1  DistinguidoDistinguido  female  58.0
# 152         1044         0       3  DistinguidoDistinguido    male  60.5
#
#      SibSp  Parch    Ticket      Fare            Cabin Embarked
# ...

# %%
#Aplicar una funcion para el nombre en donde empiece con la palabra distinguido
df["Name"]  = df["Name"].apply(lambda x : x + "Distinguido")
df
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 266         1158         0       1  DistinguidoDistinguidoDistinguido    male
# 372         1264         0       1  DistinguidoDistinguidoDistinguido    male
# 21           913         0       3  DistinguidoDistinguidoDistinguido    male
# 133         1025         0       3  DistinguidoDistinguidoDistinguido    male
# 116         1008         0       3  DistinguidoDistinguidoDistinguido    male
# ..           ...       ...     ...                                ...     ...
# 24           916         1       1  DistinguidoDistinguidoDistinguido  female
# 53           945         1       1  DistinguidoDistinguidoDistinguido  female
# 69           961         1       1  DistinguidoDistinguidoDistinguido  female
# 343         1235         1       1  DistinguidoDistinguidoDistinguido  female
# 152         1044         0       3  DistinguidoDistinguidoDistinguido    male
#
# ...

# %%
#Crear una funcion sobre la columna de genero o sexo de tal manera que male o female lo convierta a mayusculas

# %%
#Para la columna survive pasarlo después de la columna name

# %%
#Si el costo del boleto es arriba de 9 dolares, Pclass va a tener la clase premiere
