# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('../../data/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
ages = [20,21,22]

df_ages = df[df['Age'].isin(ages)]
df_ages
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 9            901         0       3
# 17           909         0       3
# 23           915         0       1
# 26           918         1       1
# 37           929         1       3
# 52           944         1       2
# 63           955         1       3
# 71           963         0       3
# 90           982         1       3
# 98           990         1       3
# 106          998         0       3
# 126         1018         0       3
# 147         1039         0       3
# 169         1061         1       3
# 176         1068         1       2
# 186         1078         1       2
# 221         1113         0       3
# 222         1114         1       2
# 223         1115         0       3
# 231         1123         1       1
# 232         1124         0       3
# 235         1127         0       3
# 237         1129         0       3
# 246         1138         1       2
# ...

# %%
df_filtrado = df[df['Age'].isin(ages) & (df['Pclass'] == 1)]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23           915         0       1  Williams, Mr. Richard Norris II    male
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 231         1123         1       1         Willard, Miss. Constance  female
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 23   21.0      0      1  PC 17597  61.3792   NaN        C
# 26   22.0      0      1    113509  61.9792   B36        C
# 231  21.0      0      0    113795  26.5500   NaN        S
# 402  22.0      0      1    112378  59.4000   NaN        C

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 9            901         0       3
# 17           909         0       3
# 23           915         0       1
# 26           918         1       1
# 37           929         1       3
# 52           944         1       2
# 63           955         1       3
# 71           963         0       3
# 90           982         1       3
# 98           990         1       3
# 106          998         0       3
# 126         1018         0       3
# 147         1039         0       3
# 169         1061         1       3
# 176         1068         1       2
# 186         1078         1       2
# 221         1113         0       3
# 222         1114         1       2
# 223         1115         0       3
# 231         1123         1       1
# 232         1124         0       3
# 235         1127         0       3
# 237         1129         0       3
# 246         1138         1       2
# ...

# %%
#Filtrar el df por genero y decir cuantos fueron male y cuantos fueron female

df_male = df[df['Sex'].isin('male') ] 
df_female = df[df['Sex'].isin('female') ]

df_male
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 #Filtrar el df por genero y decir cuantos fueron male y cuantos fueron female
# ----> 3 df_male = df[df['Sex'].isin('male') ]
#       4 df_female = df[df['Sex'].isin('female') ]
#       6 df_male
#
# File ~/Documents/NumpyPandas/.venv/lib/python3.11/site-packages/pandas/core/series.py:5559, in Series.isin(self, values)
#    5486 def isin(self, values) -> Series:
#    5487     """
#    5488     Whether elements in Series are contained in `values`.
#    5489
#    (...)
#    5557     dtype: bool
#    5558     """
# -> 5559     result = algorithms.isin(self._values, values)
#    5560     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5561         self, method="isin"
#    5562     )
#
# ...

# %%
#Ejercicio 2
# Filtrar df por edades de 30 a 35 años y decir cuantos son
df_edades =

# %%
#Ejercicio3
#Filtrar a aquellos pasajeros que sobrevivieron y que estan en 2 clase

# %%
#Filtrar a aquellos pasajeron que sobrevivieron, que estan en 2 clase y tienen una edad de 20 a 22 años y saber cuantos son

# %%
import os

# Ruta del notebook actual
current_dir = os.getcwd()

# Subir dos niveles y acceder a la carpeta 'data'
data_dir = os.path.abspath(os.path.join(current_dir, '..', '..', 'data'))

# Verificar que la carpeta 'data' existe
if os.path.exists(data_dir):
    print(f"Carpeta 'data' encontrada: {data_dir}")
    # Listar archivos en 'data'
    files = os.listdir(data_dir)
    print("Archivos disponibles en la carpeta 'data':")
    for file in files:
        print(file)
else:
    print("La carpeta 'data' no se encontró.")

# Ruta relativa desde 'cienciaDatos/pandas' hacia 'data'
data_dir_relative = os.path.join('..', '..', 'data')

# Verificar si la ruta relativa es válida
if os.path.exists(data_dir_relative):
    print(f"La ruta relativa hacia 'data' es: {data_dir_relative}")
else:
    print("No se encontró la carpeta 'data' usando la ruta relativa.")
# Out:
# Carpeta 'data' encontrada: /Users/memopispo/Documents/NumpyPandas/data
# Archivos disponibles en la carpeta 'data':
# bios.csv
# languages_dataset.csv
# tested.csv
# noc_regions.csv
# results.feather
# results.parquet
# olympics-data.xlsx
# coffee.csv
# datanumeric.txt
# results.csv
# data.txt
# cardio_train.csv
# La ruta relativa hacia 'data' es: ../../data
