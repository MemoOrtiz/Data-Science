# %%
import numpy as np
import pandas as pd

# %%
#Leer el archivo dataset la r significa row
df = pd.read_csv('../../data/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#Metodo head
#Nos permite visualizar los primeros 5 renglones del data frame
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Tail nos permite ver los últimos 5 renglones 
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#mostrar los primeros 10 renglones
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
#los ultimos 10 renglones
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
#FILTRAR POR RENGLONES 
df.Pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
df["Pclass"]
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
#Nos mostrara false todo lo que sea distinta de primera clase y true si es primera clase
df.Pclass == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Pclass, Length: 418, dtype: bool

# %%
df["Pclass"] == 1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Pclass, Length: 418, dtype: bool

# %%
#Generar dataframe para solo mostrar a los de primera clase 
#Creamos un data frame para mostrar toda la informacion del dataframe primera clase
df_1st = df[df.Pclass == 1]
df_1st
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Generar un nuevo data frame donde solo filtremos a los que sobrevivieron
df_sobre = df[df.Survived == 1]
df_sobre
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df_murieron = df[(df.Survived == 0)]
df_murieron
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
ages = [20,21,22]

# %%
df_ages = df[df["Age"].isin(ages)]
df_ages
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 9            901         0       3
# 17           909         0       3
# 23           915         0       1
# 26           918         1       1
# 37           929         1       3
# 52           944         1       2
# 63           955         1       3
# 71           963         0       3
# 90           982         1       3
# 98           990         1       3
# 106          998         0       3
# 126         1018         0       3
# 147         1039         0       3
# 169         1061         1       3
# 176         1068         1       2
# 186         1078         1       2
# 221         1113         0       3
# 222         1114         1       2
# 223         1115         0       3
# 231         1123         1       1
# 232         1124         0       3
# 235         1127         0       3
# 237         1129         0       3
# 246         1138         1       2
# ...

# %%
df_filtrado = df[df["Age"].isin(ages) & (df["Pclass"] == 1)]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23           915         0       1  Williams, Mr. Richard Norris II    male
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 231         1123         1       1         Willard, Miss. Constance  female
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 23   21.0      0      1  PC 17597  61.3792   NaN        C
# 26   22.0      0      1    113509  61.9792   B36        C
# 231  21.0      0      0    113795  26.5500   NaN        S
# 402  22.0      0      1    112378  59.4000   NaN        C

# %%
#Ejercicio1 Filtrar el data frame por genero Y decir cuantos fueron male y female
df_genero = df[df['Sex'] == 'male']
df_genero
#Filtrar  nuestro data frame por edades de 30 a 35 años y decir cuantos son
#Filtrar aquellos pasajeros que sobrevivieron y que están en segunda clase 
#Filtrar aquellos pasajeros que sobrevivieron están en segunda clase y tienen una edad de 20 a 22 años y saber cuantos son.
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../data/tested.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#Filtrar Renglones

# %%
df_pClas1 = df[df["Pclass"] == 1] 
df_pClas1
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 22           914         1       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ages = [20,21,22]
df_filtrado = df[df["Age"].isin(ages) & (df["Pclass"] == 1)]
df_filtrado
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 23           915         0       1  Williams, Mr. Richard Norris II    male
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 231         1123         1       1         Willard, Miss. Constance  female
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 23   21.0      0      1  PC 17597  61.3792   NaN        C
# 26   22.0      0      1    113509  61.9792   B36        C
# 231  21.0      0      0    113795  26.5500   NaN        S
# 402  22.0      0      1    112378  59.4000   NaN        C

# %%
#Utilizar parentesis
df_filtrado2 = df[(df["Pclass"] == 2) & (df["Survived"] == 1)]
df_filtrado2.shape
# Out:
# (30, 12)

# %%
#Filtrado por columnas
df_filtrado_Nombre = df.filter(["Name","Sex","Age"])
df_filtrado_Nombre
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
#Eliminar columnas 
df_new2 = df.drop(["Cabin","Embarked","SibSp","Parch"],axis = 1)
df_new2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# ...

# %%
#Ejercicio 
#Dado el siguiente data frame filtrarlo de tal manera que solo aparezca, nombre, genero y edad
#Una vez filtrado, filtrar que solo aparezcan los de genero  masculino y los de edad de 20 22 años


df_filtro = df.filter(["Name","Sex","Age"])
df_filtro
# Out:
#                                              Name     Sex   Age
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# 413                            Spector, Mr. Woolf    male   NaN
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5
# 416                           Ware, Mr. Frederick    male   NaN
# 417                      Peter, Master. Michael J    male   NaN
#
# [418 rows x 3 columns]

# %%
df_filtroNuevo = df_filtro[(df_filtro["Sex"] == "male") & (df_filtro["Age"].isin(ages))]
df_filtroNuevo.shape
# Out:
# (24, 3)

# %%
#Filtrar por sobrevivientes, nombre,edad y Fare
#Una vez filtrado, filtrar de tal manera los que fueron femenino y que sobrevivieron
df_filt = df.filter(["Sex","Survived","Name","Age","Fare"])
df_filt
# Out:
#         Sex  Survived                                          Name   Age  \
# 0      male         0                              Kelly, Mr. James  34.5
# 1    female         1              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2      male         0                     Myles, Mr. Thomas Francis  62.0
# 3      male         0                              Wirz, Mr. Albert  27.0
# 4    female         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..      ...       ...                                           ...   ...
# 413    male         0                            Spector, Mr. Woolf   NaN
# 414  female         1                  Oliva y Ocana, Dona. Fermina  39.0
# 415    male         0                  Saether, Mr. Simon Sivertsen  38.5
# 416    male         0                           Ware, Mr. Frederick   NaN
# 417    male         0                      Peter, Master. Michael J   NaN
#
#          Fare
# 0      7.8292
# 1      7.0000
# 2      9.6875
# 3      8.6625
# ...

# %%
df_su = df_filt[(df_filt["Sex"] == "female") & (df_filt["Survived"] == 1)]
df_su
# Out:
#         Sex  Survived                                             Name   Age  \
# 1    female         1                 Wilkes, Mrs. James (Ellen Needs)  47.0
# 4    female         1     Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# 6    female         1                             Connolly, Miss. Kate  30.0
# 8    female         1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.0
# 12   female         1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)  23.0
# ..      ...       ...                                              ...   ...
# 409  female         1                        Peacock, Miss. Treasteall   3.0
# 410  female         1                           Naughton, Miss. Hannah   NaN
# 411  female         1  Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0
# 412  female         1                   Henriksson, Miss. Jenny Lovisa  28.0
# 414  female         1                     Oliva y Ocana, Dona. Fermina  39.0
#
#          Fare
# 1      7.0000
# ...

# %%
#Concatenar
df1 = df[df["Pclass"] == 1 ]
df1.shape
# Out:
# (107, 12)

# %%
df2 = df[df["Pclass"] == 2]
df2.shape
# Out:
# (93, 12)

# %%
#concatenar dos frames y reindexar con ignore index


df_final = df1.append(df2, ignore_index = True)
df_final
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9c/0nd6phzx429bzy7lvvwctvdm0000gn/T/ipykernel_27930/322854830.py in ?()
#       1 #concatenar dos frames y reindexar con ignore index
#       2
#       3
# ----> 4 df_final = df1.append(df2, ignore_index = True)
#       5 df_final
#
# ~/Documents/NumpyPandas/.venv/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df_final = pd.concat([df1,df2],ignore_index = True)
df_final
# Out:
#      PassengerId  Survived  Pclass  \
# 0            903         0       1
# 1            904         1       1
# 2            906         1       1
# 3            912         0       1
# 4            914         1       1
# ..           ...       ...     ...
# 195         1279         0       2
# 196         1285         0       2
# 197         1293         0       2
# 198         1297         0       2
# 199         1298         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Jones, Mr. Charles Cresson    male  46.0      0
# 1        Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 2    Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 3                               Rothschild, Mr. Martin    male  55.0      1
# 4                 Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Ejercicio
#Concatenar los de primera y tercera clase 
df_pClas1 = df[df["Pclass"] == 1] 
df_pClas3 = df[df["Pclass"] == 3] 
df_primera_tercera_clase = pd.concat([df_pClas1,df_pClas3], ignore_index=True)
df_primera_tercera_clase
# Out:
#      PassengerId  Survived  Pclass  \
# 0            903         0       1
# 1            904         1       1
# 2            906         1       1
# 3            912         0       1
# 4            914         1       1
# ..           ...       ...     ...
# 320         1304         1       3
# 321         1305         0       3
# 322         1307         0       3
# 323         1308         0       3
# 324         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Jones, Mr. Charles Cresson    male  46.0      0
# 1        Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 2    Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 3                               Rothschild, Mr. Martin    male  55.0      1
# 4                 Flegenheim, Mrs. Alfred (Antoinette)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_pClas1 = df[df["Pclass"] == 1] 
df_pClas1.shape
# Out:
# (107, 12)

# %%
df_pClas2 = df[df["Pclass"] == 2] 
df_pClas2.shape
# Out:
# (93, 12)

# %%
#Concatenar las anteriores
df_resultado = pd.concat([df_pClas1,df_pClas2], ignore_index= True)
df_resultado.shape
# Out:
# (200, 12)

# %%
#Concatenar las anteriores
df_resultado = pd.concat([df_pClas1,df_pClas2], ignore_index= True)
df_resultado

# %%
df_1 = pd.DataFrame({
    "A":[1,2,3],
    "B": [4,5,6],
})
df_1
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df_2 = pd.DataFrame({
    "C" : [7, 8, 9],
    "D": [10,11,12]
})
df_2
# Out:
#    C   D
# 0  7  10
# 1  8  11
# 2  9  12

# %%
df_final = pd.concat([df_1,df_2], axis=1)
df_final
# Out:
#    A  B  C   D
# 0  1  4  7  10
# 1  2  5  8  11
# 2  3  6  9  12

# %%
#Concatenar los de 20 años,30 años y 40 años

# %%
#Ordenar ascendente que es predeterminado
#si agregamos el ascending = False, se ordenara de manera descendente


df_ordenado_edad = df.sort_values("Age", ascending = False)
df_ordenado_edad
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 236         1128         0       1
# 305         1197         1       1
# 179         1071         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Ordenar por edad y costo de ticket
#Le da prioridad a edar pero cuando exista dos edades iguales, se ordenara por costo de ticket
#Si se quiere ordenar por dos columnas se tiene que poner en una lista

#df_ordenado_edad_fare = df.sort_values(["Age","Fare"],ascending = [False,True])
df_ordenado_edad_fare = df.sort_values(["Age","Fare"], ascending = False)
df_ordenado_edad_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 81           973         0       1
# 179         1071         1       1
# 236         1128         0       1
# 305         1197         1       1
# ..           ...       ...     ...
# 211         1103         0       3
# 163         1055         0       3
# 116         1008         0       3
# 133         1025         0       3
# 266         1158         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 179  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...  female  64.0      0
# 236                           Warren, Mr. Frank Manley    male  64.0      1
# 305  Crosby, Mrs. Edward Gifford (Catherine Elizabe...  female  64.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Construya un dataframe de 4x4 y concatenelo con otro dataframe de 8x4 
# La concatenacion sera vertical

df_1 = pd.DataFrame({
    "A":[1,2,3,4],
    "B": [5,6,7,8],
    "C": [9,10,11,12],
    "D": [13,14,15,16]
})
df_2 = pd.DataFrame({
    "A": [1, 2, 3, 4, 5, 6, 7, 8],
    "B": [9, 10, 11, 12, 13, 14, 15, 16],
    "C": [17, 18, 19, 20, 21, 22, 23, 24],
    "D": [25, 26, 27, 28, 29, 30, 31, 32]
})

df_final = pd.concat([df_1,df_2], ignore_index = True)
df_final
# Out:
#     A   B   C   D
# 0   1   5   9  13
# 1   2   6  10  14
# 2   3   7  11  15
# 3   4   8  12  16
# 4   1   9  17  25
# 5   2  10  18  26
# 6   3  11  19  27
# 7   4  12  20  28
# 8   5  13  21  29
# 9   6  14  22  30
# 10  7  15  23  31
# 11  8  16  24  32

# %%
#Utilizando el df primero creado, concatenar con otro dataframe de 4x3 concatenado horizontalmente
df_1 = pd.DataFrame({
    "A":[1,2,3,4],
    "B": [5,6,7,8],
    "C": [9,10,11,12],
    "D": [13,14,15,16]
})

df_3 = pd.DataFrame({
    "E": [17, 18, 19, 20],
    "F": [21, 22, 23, 24],
    "G": [25, 26, 27, 28]
})

df_final2 = pd.concat([df_1,df_3], axis = 1, ignore_index = False)
df_final2
# Out:
#    A  B   C   D   E   F   G
# 0  1  5   9  13  17  21  25
# 1  2  6  10  14  18  22  26
# 2  3  7  11  15  19  23  27
# 3  4  8  12  16  20  24  28

# %%
# Del df de titanic, ordenar los valores de la ultima clase a la primera clase

df_ultima_primera = df.sort_values("Pclass", ascending = False)
df_ultima_primera
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 232         1124         0       3
# 249         1141         1       3
# 244         1136         0       3
# 243         1135         0       3
# ..           ...       ...     ...
# 239         1131         1       1
# 158         1050         0       1
# 240         1132         1       1
# 77           969         1       1
# 236         1128         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                     Kelly, Mr. James    male  34.5      0
# 232                            Wiklund, Mr. Karl Johan    male  21.0      1
# 249          Khalil, Mrs. Betros (Zahie Maria" Elias)"  female   NaN      1
# 244          Johnston, Master. William Arthur Willie""    male   NaN      1
# 243                                 Hyman, Mr. Abraham    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Ordenar por numero de ticket y edad
